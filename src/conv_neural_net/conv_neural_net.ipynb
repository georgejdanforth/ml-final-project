# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np
import scipy.signal as sg
from utils import *

# %%
# superclass of modules
class Module:
    """
    Module is a super class. It could be a single layer, or a multilayer perceptron.
    """
    
    def __init__(self):
        self.train = True
        return
    
    def forward(self, _input):
        """
        h = f(z); z is the input, and h is the output.
        
        Inputs:
        _input: z
        
        Returns:
        output h
        """
        pass
    
    def backward(self, _input, _gradOutput):
        """
        Compute:
        gradient w.r.t. _input
        gradient w.r.t. trainable parameters
        
        Inputs:
        _input: z
        _gradOutput: dL/dh
        
        Returns:
        gradInput: dL/dz
        """
        pass
        
    def parameters(self):
        """
        Return the value of trainable parameters and its corresponding gradient (Used for grandient descent)
        
        Returns:
        params, gradParams
        """
        pass
    
    def training(self):
        """
        Turn the module into training mode.(Only useful for Dropout layer)
        Ignore it if you are not using Dropout.
        """
        self.train = True
        
    def evaluate(self):
        """
        Turn the module into evaluate mode.(Only useful for Dropout layer)
        Ignore it if you are not using Dropout.
        """
        self.train = False

# %%
class Sequential(Module):
    """
    Sequential provides a way to plug layers together in a feed-forward manner.
    """
    def __init__(self):
        Module.__init__(self)
        self.layers = [] # layers contain all the layers in order
    
    def add(self, layer):
        self.layers.append(layer) # Add another layer at the end
    
    def size(self):
        return len(self.layers) # How many layers.
    
    def forward(self, _input):
        """
        Feed forward through all the layers, and return the output of the last layer
        """
        # self._inputs saves the input of each layer
        # self._inputs[i] is the input of i-th layer
        self._inputs = [_input]
        
        for i in range(self.size()):
            self._inputs.append(self.layers[i].forward(self._inputs[i]))
        
        # The last element of self._inputs is the output of last layer
        self._output = self._inputs[-1]
        return self._output
    
    def backward(self, _input, _gradOutput):
        """
        Backpropogate through all the layers using chain rule.
        """
        # self._gradInputs[i] is the gradient of loss w.r.t. the input of i-th layer
        self._gradInputs = [None] * (self.size() + 1)
        self._gradInputs[self.size()] = _gradOutput

        for i in range(self.size(), 0, -1):
            self._gradInputs[i-1] = self.layers[i-1].backward(self._inputs[i-1], self._gradInputs[i])
        
        self._gradInput = self._gradInputs[0]
        return self._gradInput
    
    def parameters(self):
        """
        Return trainable parameters and its corresponding gradient in a nested list
        """
        params = []
        gradParams = []
        for m in self.layers:
            _p, _g = m.parameters()
            if _p is not None:
                params.append(_p)
                gradParams.append(_g)
        return params, gradParams

    def training(self):
        """
        Turn all the layers into training mode
        """
        Module.training(self)
        for m in self.layers:
            m.training()
    
    def evaluate(self):
        """
        Turn all the layers into evaluate mode
        """
        Module.evaluate(self)
        for m in self.layers:
            m.evaluate()

# %%
class Convolutional(Module):
    """
    Convolutional layer
    """
    def __init__(self, inputLength, inputDepth, filterLength, filterDepth):
        Module.__init__(self)
        # Initalization
        stdv = 1./np.sqrt(inputLength)
        
        self.weight = np.random.uniform(-stdv, stdv, (filterLength, inputDepth, filterDepth))
        self.gradWeight = np.ndarray((filterLength, inputDepth, filterDepth))
        self.bias = np.random.uniform(-stdv, stdv, filterDepth)
        self.gradBias = np.ndarray(filterDepth)
        
    def forward(self, _input):
        """
        output = W * input + b convolution
        
        _input:
        N x inputLength x inputDepth matrix
        
        """
        inputDepth = self.weight.shape[1]
        filterDepth = self.weight.shape[2]
        
        _input = _input.reshape(_input.shape[0],-1,inputDepth)
        
        self._output = []
        for i in range(filterDepth):
            self._output.append(sg.correlate(_input, np.expand_dims(np.take(self.weight,i,2),0), 'valid') + self.bias[i])
        self._output = np.array(self._output)
        self._output = self._output.reshape(self._output.shape[1],self._output.shape[2],self._output.shape[0])

        return self._output
    
    def backward(self, _input, _gradOutput):
        """
        _input:
        N x inputLength x inputDepth matrix
        _gradOutputSize:
        N x outputLength x outputDepth matrix
        """
        filterLength = self.weight.shape[0]
        inputDepth = self.weight.shape[1]
        filterDepth = self.weight.shape[2]
        
        _input = _input.reshape(_input.shape[0],-1,inputDepth)
        _gradOutput = _gradOutput.reshape(_gradOutput.shape[0],-1,filterDepth)
        
        for i in range(filterDepth):
            self.gradWeight[:,:,i] = np.squeeze(sg.correlate(_input, np.expand_dims(np.take(_gradOutput,i,2),2), 'valid'))
        
        self.gradBias = np.sum(_gradOutput, axis=(0,1))
        
        self._gradInput = []
        for i in range(inputDepth):
            self._gradInput.append(sg.correlate(np.pad(_gradOutput, ((0,0),(filterLength-1,filterLength-1),(0,0)), 'constant'), np.expand_dims(np.take(self.weight,i,1),0), 'valid'))
        self._gradInput = np.array(self._gradInput)
        self._gradInput = self._gradInput.reshape(self._gradInput.shape[1],self._gradInput.shape[2],self._gradInput.shape[0])

        return self._gradInput
        
    def parameters(self):
        """
        Return weight and bias and their g
        """
        return [self.weight, self.bias], [self.gradWeight, self.gradBias]

# %%
class FullyConnected(Module):
    """
    Fully connected layer
    """
    def __init__(self, inputSize, outputSize):
        Module.__init__(self)
        # Initalization
        stdv = 1./np.sqrt(inputSize)
        
        self.weight = np.random.uniform(-stdv, stdv, (inputSize, outputSize))
        self.gradWeight = np.ndarray((inputSize, outputSize))
        self.bias = np.random.uniform(-stdv, stdv, outputSize)
        self.gradBias = np.ndarray(outputSize)
        
    def forward(self, _input):
        """
        output = W * input + b
        
        _input:
        N x inputSize matrix
        
        """
        _input = _input.reshape(_input.shape[0],-1)
        
        self._output = np.dot(_input, self.weight) + self.bias
        return self._output
    
    def backward(self, _input, _gradOutput):
        """
        _input:
        N x inputSize matrix
        _gradOutputSize:
        N x outputSize matrix
        """
        _input = _input.reshape(_input.shape[0],-1)
        _gradOutput = _gradOutput.reshape(_gradOutput.shape[0],-1)
        
        self.gradWeight = np.dot(_input.T, _gradOutput)
        self.gradBias = np.sum(_gradOutput, axis=0)

        self._gradInput = np.dot(_gradOutput, self.weight.T)
        return self._gradInput
        
    def parameters(self):
        """
        Return weight and bias and their g
        """
        return [self.weight, self.bias], [self.gradWeight, self.gradBias]

# %%
class ReLU(Module):
    """
    ReLU activation, not trainable.
    """
    def __init__(self):
        Module.__init__(self)
        return
    
    def forward(self, _input):
        """
        output = max(0, input)
        
        _input:
        N x d matrix
        """
        self._output = np.maximum(0, _input)
        return self._output
    
    def backward(self, _input, _gradOutput):
        """
        gradInput = gradOutput * mask
        mask = _input > 0
        
        _input:
        N x d matrix
        
        _gradOutput:
        N x d matrix
        """        
        self._gradInput = _gradOutput * (_input > 0)
        return self._gradInput
        
    def parameters(self):
        """
        No trainable parametersm, return None
        """
        return None, None

# %%
# Optional
class Logistic(Module):
    """
    Logistic activation, not trainable.
    """
    def __init__(self):
        Module.__init__(self)
        return
    
    def forward(self, _input):
        self._output = 0 #YOUR CODE HERE
        return self._output
    
    def backward(self, _input, _gradOutput):
        self._gradInput = 0 #YOUR CODE HERE
        return self._gradInput
        
    def parameters(self):
        return None, None

# %%
# Optional
class Dropout(Module):
    """
    A dropout layer
    """
    def __init__(self, p = 0.5):
        Module.__init__(self)
        self.p = p #self.p is the drop rate, if self.p is 0, then it's a identity layer
        
    def forward(self, _input):
        self._output = _input
        # YOUR CODE HERE
        # Need to take care of training mode and evaluation mode
        return self._output
    
    def backward(self, _input, _gradOutput):
        self._gradInput = _gradOutput
        #YOUR CODE HERE
        return self._gradInput
    
    def parameters(self):
        """
        No trainable parameters.
        """
        return None, None

# %%
class SoftMaxLoss(object):
    def __init__(self):
        return
        
    def forward(self, _input, _label):
        """
        Softmax and cross entropy loss layer. Should return a scalar, since it's a
        loss. (It's almost identical to what in hw2)

        _input: N x C
        _labels: N x C, one-hot

        Returns: loss (scalar)
        """
        self._output = -np.sum(_label * (_input - np.log(np.sum(np.exp(_input), axis=1)).reshape(1, -1).T))
        return self._output
    
    def backward(self, _input, _label):
        self._gradInput = np.exp(_input)/np.sum(np.exp(_input), axis=1).reshape(1, -1).T - _label
        return self._gradInput

# %%
# Test softmaxloss, the relative error should be small enough
def test_sm():
    crit = SoftMaxLoss()
    gt = np.zeros((3, 10))
    gt[np.arange(3), np.array([1,2,3])] = 1
    x = np.random.random((3,10))
    def test_f(x):
        return crit.forward(x, gt)

    crit.forward(x, gt)

    gradInput = crit.backward(x, gt)
    gradInput_num = numeric_gradient(test_f, x, 1, 1e-6)
    #print(gradInput)
    #print(gradInput_num)
    print(relative_error(gradInput, gradInput_num, 1e-8))
    
test_sm()
# Out:
# 3.68002421576e-09

# %%
# Test modules, all the relative errors should be small enough
def test_module(model):

    model.evaluate()

    crit = TestCriterion()
    gt = np.random.random((3,10))
    x = np.random.random((3,10))
    def test_f(x):
        return crit.forward(model.forward(x), gt)

    gradInput = model.backward(x, crit.backward(model.forward(x), gt))
    gradInput_num = numeric_gradient(test_f, x, 1, 1e-6)
    print(relative_error(gradInput, gradInput_num, 1e-8))

# Test fully connected
model = FullyConnected(10, 10)
test_module(model)

# Test ReLU
model = ReLU()
test_module(model)

# Test Dropout
# model = Dropout()
# test_module(model)
# You can only test dropout in evaluation mode.

# Test Sequential
model = Sequential()
model.add(FullyConnected(10, 10))
model.add(ReLU())
#model.add(Dropout())
test_module(model)
# Out:
# 5.91877788997e-09
# 7.36022825478e-10
# 5.66239988236e-09

# %%
# Test gradient descent, the loss should be lower and lower
trainX = np.random.random((10,25,15))

model = Sequential()
model.add(Convolutional(25,15, 6,20))
model.add(ReLU())
#model.add(Dropout())
model.add(Convolutional(20,20, 11,5))
model.add(FullyConnected(50,1))

crit = TestCriterion()

it = 0
state = None
while True:
    output = model.forward(trainX)
    loss = crit.forward(output, None)
    if it % 100 == 0:
        print(loss)
    doutput = crit.backward(output, None)
    model.backward(trainX, doutput)
    params, gradParams = model.parameters()
    sgd(params, gradParams, 0.0005, 0.8)
    if it > 1000:
        break
    it += 1
# Out:
# 0.605113132029
# 0.115723470132
# 0.0538878716302
# 0.0229326470955
# 0.0169303449212
# 0.0133090239861
# 0.00981827050048
# 0.00814233107121
# 0.00490944456639
# 0.00501439667232
# 0.00366598696324

# %% [markdown]
# Now we start to work on real data.

# %%
import MNIST_utils
data_fn = "CLEAN_MNIST_SUBSETS.h5"

# We only consider large set this time
print("Load large trainset.")
Xlarge,Ylarge = MNIST_utils.load_data(data_fn, "large_train")
print(Xlarge.shape)
print(Ylarge.shape)

print("Load valset.")
Xval,Yval = MNIST_utils.load_data(data_fn, "val")
print(Xval.shape)
print(Yval.shape)
# Out:
# Load large trainset.
# (7000L, 576L)
# (7000L, 10L)
# Load valset.
# (2000L, 576L)
# (2000L, 10L)

# %%
def predict(X, model):
    """
    Evaluate the soft predictions of the model.
    Input:
    X : N x d array (no unit terms)
    model : a multi-layer perceptron
    Output:
    yhat : N x C array
        yhat[n][:] contains the score over C classes for X[n][:]
    """
    return model.forward(X)

def error_rate(X, Y, model):
    """
    Compute error rate (between 0 and 1) for the model
    """
    model.evaluate()
    res = 1 - (model.forward(X).argmax(-1) == Y.argmax(-1)).mean()
    model.training()
    return res

from copy import deepcopy

def runTrainVal(X,Y,model,Xval,Yval,trainopt):
    """
    Run the train + evaluation on a given train/val partition
    trainopt: various (hyper)parameters of the training procedure
    During training, choose the model with the lowest validation error. (early stopping)
    """
    
    eta = trainopt['eta']
    
    N = X.shape[0] # number of data points in X
    
    # Save the model with lowest validation error
    minValError = np.inf
    saved_model = None
    
    shuffled_idx = np.random.permutation(N)
    start_idx = 0
    for iteration in range(trainopt['maxiter']):
        if iteration % int(trainopt['eta_frac'] * trainopt['maxiter']) == 0:
            eta *= trainopt['etadrop']
        # form the next mini-batch
        stop_idx = min(start_idx + trainopt['batch_size'], N)
        batch_idx = range(N)[int(start_idx):int(stop_idx)]
        bX = X[shuffled_idx[batch_idx],:]
        bY = Y[shuffled_idx[batch_idx],:]

        score = model.forward(bX)
        loss = crit.forward(score, bY)
        # print(loss)
        dscore = crit.backward(score, bY)
        model.backward(bX, dscore)
        
        # Update the data using 
        params, gradParams = model.parameters()
        sgd(params, gradParams, eta, weight_decay = trainopt['lambda'])    
        start_idx = stop_idx % N
        
        if (iteration % trainopt['display_iter']) == 0:
            #compute train and val error; multiply by 100 for readability (make it percentage points)
            trainError = 100 * error_rate(X, Y, model)
            valError = 100 * error_rate(Xval, Yval, model)
            print('{:8} batch loss: {:.3f} train error: {:.3f} val error: {:.3f}'.format(iteration, loss, trainError, valError))
            
            if valError < minValError:
                saved_model = deepcopy(model)
                minValError = valError
        
    return saved_model, minValError, trainError

# %%
def build_model(input_size, hidden_size, output_size, activation_func = 'ReLU', dropout = 0):
    """
    Build the model:
    input_size: the dimension of input data
    hidden_size: the dimension of hidden vector
    output_size: the output size of final layer.
    activation_func: ReLU, Logistic, Tanh, etc. (Need to be implemented by yourself)
    dropout: the dropout rate: if dropout == 0, this is equivalent to no dropout
    """
    model = Sequential()
    model.add(FullyConnected(input_size, hidden_size))
    model.add(ReLU())
    model.add(FullyConnected(hidden_size, output_size))
    
    return model

# %%
# -- training options
trainopt = {
    'eta': .01,   # initial learning rate
    'maxiter': 20000,   # max number of iterations (updates) of SGD
    'display_iter': 500,  # display batch loss every display_iter updates
    'batch_size': 100,  
    'etadrop': .5, # when dropping eta, multiply it by this number (e.g., .5 means halve it)
    'eta_frac': .25  #
}

NFEATURES = Xlarge.shape[1]

# we will maintain a record of models trained for different values of lambda
# these will be indexed directly by lambda value itself
trained_models = dict()

# set the (initial?) set of lambda values to explore
lambdas = np.array([0, 0.001, 0.01, 0.1])
hidden_sizes = np.array([10])
    
for lambda_ in lambdas:
    for hidden_size_ in hidden_sizes:
        trainopt['lambda'] = lambda_
        model = build_model(NFEATURES, hidden_size_, 10, dropout = 0)
        crit = SoftMaxLoss()
        # -- model trained on large train set
        trained_model,valErr,trainErr = runTrainVal(Xlarge, Ylarge, model, Xval, Yval, trainopt)
        trained_models[(lambda_, hidden_size_)] = {'model': trained_model, "val_err": valErr, "train_err": trainErr }
        print('train set model: -> lambda= %.4f, train error: %.2f, val error: %.2f' % (lambda_, trainErr, valErr))
    
best_trained_lambda = 0.
best_trained_model = None
best_trained_val_err = 100.
for (lambda_, hidden_size_), results in trained_models.items():
    print('lambda= %.4f, hidden size: %5d, val error: %.2f' %(lambda_, hidden_size_, results['val_err']))
    if results['val_err'] < best_trained_val_err:
        best_trained_val_err = results['val_err']
        best_trained_model = results['model']
        best_trained_lambda = lambda_

print("Best train model val err:", best_trained_val_err)
print("Best train model lambda:", best_trained_lambda)
# Out:
#        0 batch loss: 235.104 train error: 88.814 val error: 88.350
#      500 batch loss: 22.756 train error: 6.614 val error: 9.250
#     1000 batch loss: 18.214 train error: 5.629 val error: 8.850
#     1500 batch loss: 18.165 train error: 4.286 val error: 9.350
#     2000 batch loss: 15.896 train error: 3.743 val error: 8.200
#     2500 batch loss: 9.335 train error: 2.800 val error: 8.550
#     3000 batch loss: 2.770 train error: 2.300 val error: 8.100
#     3500 batch loss: 1.057 train error: 1.243 val error: 8.250
#     4000 batch loss: 17.351 train error: 7.800 val error: 11.850
#     4500 batch loss: 18.937 train error: 4.814 val error: 9.650
#     5000 batch loss: 29.857 train error: 4.114 val error: 9.800
#     5500 batch loss: 11.199 train error: 2.857 val error: 9.750
#     6000 batch loss: 9.463 train error: 2.414 val error: 10.050
#     6500 batch loss: 5.110 train error: 2.514 val error: 10.200
#     7000 batch loss: 2.397 train error: 2.043 val error: 10.350
#     7500 batch loss: 6.674 train error: 2.043 val error: 9.950
#     8000 batch loss: 3.491 train error: 3.057 val error: 10.800
#     8500 batch loss: 12.779 train error: 1.643 val error: 10.000
#     9000 batch loss: 4.876 train error: 1.286 val error: 10.350
#     9500 batch loss: 2.909 train error: 0.914 val error: 10.550
#    10000 batch loss: 1.628 train error: 0.786 val error: 10.450
#    10500 batch loss: 1.422 train error: 0.700 val error: 10.000
#    11000 batch loss: 3.884 train error: 0.643 val error: 9.800
#    11500 batch loss: 2.381 train error: 0.629 val error: 10.150
#    12000 batch loss: 7.809 train error: 0.371 val error: 10.050
#    12500 batch loss: 3.046 train error: 0.314 val error: 10.000
#    13000 batch loss: 1.470 train error: 0.329 val error: 10.200
#    13500 batch loss: 1.068 train error: 0.229 val error: 10.000
#    14000 batch loss: 1.002 train error: 0.257 val error: 10.050
#    14500 batch loss: 2.237 train error: 0.214 val error: 9.700
#    15000 batch loss: 1.931 train error: 0.229 val error: 10.200
#    15500 batch loss: 6.101 train error: 0.200 val error: 9.900
#    16000 batch loss: 2.617 train error: 0.186 val error: 9.800
#    16500 batch loss: 1.175 train error: 0.214 val error: 9.750
#    17000 batch loss: 0.828 train error: 0.214 val error: 9.750
#    17500 batch loss: 0.784 train error: 0.214 val error: 9.650
#    18000 batch loss: 1.733 train error: 0.186 val error: 9.550
#    18500 batch loss: 1.700 train error: 0.200 val error: 9.550
#    19000 batch loss: 5.728 train error: 0.186 val error: 9.650
#    19500 batch loss: 2.299 train error: 0.186 val error: 9.550
# train set model: -> lambda= 0.0000, train error: 0.19, val error: 8.10
#        0 batch loss: 229.887 train error: 87.629 val error: 86.850
#      500 batch loss: 22.265 train error: 7.057 val error: 8.350
#     1000 batch loss: 31.310 train error: 7.543 val error: 10.100
#     1500 batch loss: 21.731 train error: 5.086 val error: 7.750
#     2000 batch loss: 8.912 train error: 4.114 val error: 8.800
#     2500 batch loss: 3.490 train error: 2.900 val error: 8.150
#     3000 batch loss: 7.613 train error: 3.386 val error: 9.350
#     3500 batch loss: 1.830 train error: 2.314 val error: 8.100
#     4000 batch loss: 20.439 train error: 8.143 val error: 9.700
#     4500 batch loss: 4.199 train error: 1.400 val error: 7.850
#     5000 batch loss: 2.887 train error: 1.271 val error: 7.450
#     5500 batch loss: 1.342 train error: 0.629 val error: 7.550
#     6000 batch loss: 0.580 train error: 0.600 val error: 8.150
#     6500 batch loss: 1.243 train error: 0.257 val error: 7.750
#     7000 batch loss: 1.067 train error: 0.257 val error: 7.850
#     7500 batch loss: 0.763 train error: 0.271 val error: 8.050
#     8000 batch loss: 1.348 train error: 0.171 val error: 8.050
#     8500 batch loss: 0.945 train error: 0.100 val error: 8.050
#     9000 batch loss: 0.579 train error: 0.157 val error: 8.150
#     9500 batch loss: 0.313 train error: 0.100 val error: 8.150
#    10000 batch loss: 0.567 train error: 0.086 val error: 8.200
#    10500 batch loss: 0.476 train error: 0.043 val error: 8.250
#    11000 batch loss: 0.425 train error: 0.071 val error: 8.300
#    11500 batch loss: 0.847 train error: 0.071 val error: 8.300
#    12000 batch loss: 0.554 train error: 0.029 val error: 8.300
#    12500 batch loss: 0.371 train error: 0.029 val error: 8.250
#    13000 batch loss: 0.220 train error: 0.029 val error: 8.300
#    13500 batch loss: 0.420 train error: 0.029 val error: 8.350
#    14000 batch loss: 0.363 train error: 0.029 val error: 8.250
#    14500 batch loss: 0.328 train error: 0.029 val error: 8.250
#    15000 batch loss: 0.658 train error: 0.014 val error: 8.450
#    15500 batch loss: 0.408 train error: 0.014 val error: 8.300
#    16000 batch loss: 0.277 train error: 0.014 val error: 8.300
#    16500 batch loss: 0.178 train error: 0.014 val error: 8.300
#    17000 batch loss: 0.358 train error: 0.014 val error: 8.400
#    17500 batch loss: 0.307 train error: 0.014 val error: 8.450
#    18000 batch loss: 0.281 train error: 0.014 val error: 8.350
#    18500 batch loss: 0.563 train error: 0.014 val error: 8.400
#    19000 batch loss: 0.363 train error: 0.014 val error: 8.300
#    19500 batch loss: 0.246 train error: 0.014 val error: 8.450
# train set model: -> lambda= 0.0010, train error: 0.01, val error: 7.45
#        0 batch loss: 232.410 train error: 89.243 val error: 88.650
#      500 batch loss: 25.957 train error: 9.057 val error: 10.700
#     1000 batch loss: 8.681 train error: 5.071 val error: 8.150
#     1500 batch loss: 21.295 train error: 6.400 val error: 9.800
#     2000 batch loss: 6.679 train error: 2.514 val error: 7.700
#     2500 batch loss: 4.703 train error: 5.114 val error: 10.200
#     3000 batch loss: 6.721 train error: 2.571 val error: 9.000
#     3500 batch loss: 4.491 train error: 1.971 val error: 8.700
#     4000 batch loss: 4.106 train error: 1.929 val error: 8.750
#     4500 batch loss: 0.360 train error: 1.186 val error: 8.650
#     5000 batch loss: 2.548 train error: 1.386 val error: 9.250
#     5500 batch loss: 1.372 train error: 0.443 val error: 8.700
#     6000 batch loss: 0.882 train error: 0.471 val error: 8.600
#     6500 batch loss: 2.303 train error: 0.243 val error: 8.500
#     7000 batch loss: 1.051 train error: 0.200 val error: 8.550
#     7500 batch loss: 1.016 train error: 0.143 val error: 8.700
#     8000 batch loss: 0.151 train error: 0.129 val error: 8.700
#     8500 batch loss: 1.306 train error: 0.129 val error: 8.650
#     9000 batch loss: 0.698 train error: 0.086 val error: 8.750
#     9500 batch loss: 0.331 train error: 0.057 val error: 8.600
#    10000 batch loss: 1.639 train error: 0.057 val error: 8.500
#    10500 batch loss: 0.634 train error: 0.057 val error: 8.550
#    11000 batch loss: 0.568 train error: 0.057 val error: 8.550
#    11500 batch loss: 0.121 train error: 0.057 val error: 8.600
#    12000 batch loss: 0.882 train error: 0.057 val error: 8.600
#    12500 batch loss: 0.474 train error: 0.057 val error: 8.550
#    13000 batch loss: 0.246 train error: 0.057 val error: 8.550
#    13500 batch loss: 1.390 train error: 0.057 val error: 8.650
#    14000 batch loss: 0.491 train error: 0.057 val error: 8.650
#    14500 batch loss: 0.463 train error: 0.057 val error: 8.700
#    15000 batch loss: 0.103 train error: 0.057 val error: 8.650
#    15500 batch loss: 0.692 train error: 0.057 val error: 8.700
#    16000 batch loss: 0.387 train error: 0.057 val error: 8.700
#    16500 batch loss: 0.206 train error: 0.057 val error: 8.600
#    17000 batch loss: 1.291 train error: 0.043 val error: 8.650
#    17500 batch loss: 0.426 train error: 0.043 val error: 8.550
#    18000 batch loss: 0.395 train error: 0.043 val error: 8.600
#    18500 batch loss: 0.088 train error: 0.043 val error: 8.650
#    19000 batch loss: 0.613 train error: 0.043 val error: 8.750
#    19500 batch loss: 0.355 train error: 0.043 val error: 8.700
# train set model: -> lambda= 0.0100, train error: 0.04, val error: 7.70
#        0 batch loss: 232.951 train error: 78.657 val error: 78.000
#      500 batch loss: 13.150 train error: 5.900 val error: 7.500
#     1000 batch loss: 19.950 train error: 5.957 val error: 9.100
#     1500 batch loss: 27.865 train error: 6.314 val error: 10.250
#     2000 batch loss: 6.088 train error: 3.729 val error: 8.900
#     2500 batch loss: 11.255 train error: 4.943 val error: 10.550
#     3000 batch loss: 3.754 train error: 3.371 val error: 9.150
#     3500 batch loss: 2.972 train error: 2.386 val error: 9.300
#     4000 batch loss: 1.822 train error: 1.114 val error: 8.950
#     4500 batch loss: 2.026 train error: 1.271 val error: 9.300
#     5000 batch loss: 1.789 train error: 0.457 val error: 9.000
#     5500 batch loss: 0.761 train error: 0.257 val error: 8.900
#     6000 batch loss: 1.616 train error: 0.086 val error: 9.100
#     6500 batch loss: 0.265 train error: 0.257 val error: 9.000
#     7000 batch loss: 0.619 train error: 0.057 val error: 8.800
#     7500 batch loss: 0.273 train error: 0.043 val error: 9.000
#     8000 batch loss: 0.727 train error: 0.057 val error: 9.100
#     8500 batch loss: 0.617 train error: 0.029 val error: 9.100
#     9000 batch loss: 0.372 train error: 0.043 val error: 9.200
#     9500 batch loss: 0.820 train error: 0.014 val error: 9.200
#    10000 batch loss: 0.159 train error: 0.043 val error: 9.050
#    10500 batch loss: 0.315 train error: 0.014 val error: 9.100
#    11000 batch loss: 0.199 train error: 0.014 val error: 9.050
#    11500 batch loss: 0.469 train error: 0.014 val error: 9.200
#    12000 batch loss: 0.443 train error: 0.014 val error: 9.050
#    12500 batch loss: 0.293 train error: 0.014 val error: 9.100
#    13000 batch loss: 0.627 train error: 0.014 val error: 9.100
#    13500 batch loss: 0.145 train error: 0.014 val error: 9.000
#    14000 batch loss: 0.260 train error: 0.014 val error: 9.100
#    14500 batch loss: 0.162 train error: 0.014 val error: 9.100
#    15000 batch loss: 0.381 train error: 0.014 val error: 9.050
#    15500 batch loss: 0.371 train error: 0.014 val error: 9.000
#    16000 batch loss: 0.245 train error: 0.014 val error: 9.050
#    16500 batch loss: 0.529 train error: 0.014 val error: 9.250
#    17000 batch loss: 0.134 train error: 0.014 val error: 9.050
#    17500 batch loss: 0.227 train error: 0.014 val error: 9.000
#    18000 batch loss: 0.146 train error: 0.014 val error: 9.050
#    18500 batch loss: 0.337 train error: 0.014 val error: 9.150
#    19000 batch loss: 0.342 train error: 0.014 val error: 9.150
#    19500 batch loss: 0.221 train error: 0.000 val error: 9.200
# train set model: -> lambda= 0.1000, train error: 0.00, val error: 7.50
# lambda= 0.0010, hidden size:    10, val error: 7.45
# lambda= 0.0100, hidden size:    10, val error: 7.70
# lambda= 0.1000, hidden size:    10, val error: 7.50
# lambda= 0.0000, hidden size:    10, val error: 8.10
# Best train model val err: 7.45
# Best train model lambda: 0.001

# %%
#Generate a Kaggle submission file using `model`
kaggleX = MNIST_utils.load_data(data_fn, 'kaggle')
kaggleYhat = predict(kaggleX, best_trained_model).argmax(-1)
save_submission('submission-mnist.csv', kaggleYhat)
# Out:
# ('Saved:', 'submission-mnist.csv')
